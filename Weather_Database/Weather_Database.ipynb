# %%
# Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key
import time
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000,high=180.000,size=2000)
lat_lngs = zip(lats,lngs)

# %%
# Add the lats and longs to a list
coordinates = list(lat_lngs)

# %%
# List for holding the cities.
cities = []
# Nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 752

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data
city_data = []
#Print the beginning of the logging
print("Beginning Data Retrieval   ")
print("---------------------------")

#Create counters
record_count = 1
set_count = 1

# Loop through all the cities in the list
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >=50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    #Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    #Log the URL, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
       
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ---------------------------
# Processing Record 1 of Set 1 | torbay
# Processing Record 2 of Set 1 | kutum
# Processing Record 3 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 4 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 1 | yeppoon
# Processing Record 6 of Set 1 | mataura
# Processing Record 7 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 8 of Set 1 | vaini
# Processing Record 9 of Set 1 | thompson
# Processing Record 10 of Set 1 | butaritari
# Processing Record 11 of Set 1 | hermanus
# Processing Record 12 of Set 1 | cabo san lucas
# Processing Record 13 of Set 1 | bluff
# Processing Record 14 of Set 1 | comodoro rivadavia
# Processing Record 15 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 16 of Set 1 | jiwani
# Processing Record 17 of Set 1 | saint-pierre
# Processing Record 18 of Set 1 | gazli
# Processing Record 19 of Set 1 | isangel
# Processing Record 20 of Set 1 | ormond beach
# Processing Record 21 of Set 1 | eureka
# Processing Record 22 of Set 1 | hilo
# Processing Record 23 of Set 1 | san carlos de bariloche
# Processing Record 24 of Set 1 | kamenskoye
# City not found. Skipping...
# Processing Record 25 of Set 1 | yellowknife
# Processing Record 26 of Set 1 | hobart
# Processing Record 27 of Set 1 | albany
# Processing Record 28 of Set 1 | igrim
# Processing Record 29 of Set 1 | ushuaia
# Processing Record 30 of Set 1 | upernavik
# Processing Record 31 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 32 of Set 1 | havre-saint-pierre
# Processing Record 33 of Set 1 | maragogi
# Processing Record 34 of Set 1 | khonuu
# City not found. Skipping...
# Processing Record 35 of Set 1 | lebu
# Processing Record 36 of Set 1 | caravelas
# Processing Record 37 of Set 1 | porbandar
# Processing Record 38 of Set 1 | norman wells
# Processing Record 39 of Set 1 | puerto ayora
# Processing Record 40 of Set 1 | bam
# Processing Record 41 of Set 1 | ilek
# Processing Record 42 of Set 1 | avarua
# Processing Record 43 of Set 1 | lebanon
# Processing Record 44 of Set 1 | saskylakh
# Processing Record 45 of Set 1 | busselton
# Processing Record 46 of Set 1 | kandrian
# Processing Record 47 of Set 1 | mar del plata
# Processing Record 48 of Set 1 | chuy
# Processing Record 49 of Set 1 | atuona
# Processing Record 50 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 1 of Set 2 | thabazimbi
# Processing Record 2 of Set 2 | nadym
# Processing Record 3 of Set 2 | college
# Processing Record 4 of Set 2 | warrington
# Processing Record 5 of Set 2 | grand gaube
# Processing Record 6 of Set 2 | daru
# Processing Record 7 of Set 2 | souillac
# Processing Record 8 of Set 2 | provideniya
# Processing Record 9 of Set 2 | grindavik
# Processing Record 10 of Set 2 | north platte
# Processing Record 11 of Set 2 | georgetown
# Processing Record 12 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 13 of Set 2 | airai
# Processing Record 14 of Set 2 | qaanaaq
# Processing Record 15 of Set 2 | dorobantu
# Processing Record 16 of Set 2 | kouqian
# Processing Record 17 of Set 2 | jatai
# Processing Record 18 of Set 2 | rikitea
# Processing Record 19 of Set 2 | port shepstone
# Processing Record 20 of Set 2 | kununurra
# Processing Record 21 of Set 2 | tasiilaq
# Processing Record 22 of Set 2 | arraial do cabo
# Processing Record 23 of Set 2 | barrow
# Processing Record 24 of Set 2 | severo-kurilsk
# Processing Record 25 of Set 2 | qeshm
# Processing Record 26 of Set 2 | lompoc
# Processing Record 27 of Set 2 | hithadhoo
# Processing Record 28 of Set 2 | kapaa
# Processing Record 29 of Set 2 | jamestown
# Processing Record 30 of Set 2 | constantine
# Processing Record 31 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 32 of Set 2 | qaqortoq
# Processing Record 33 of Set 2 | hasaki
# Processing Record 34 of Set 2 | jolo
# Processing Record 35 of Set 2 | karratha
# Processing Record 36 of Set 2 | kingman
# Processing Record 37 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 38 of Set 2 | esperance
# Processing Record 39 of Set 2 | maanshan
# Processing Record 40 of Set 2 | arona
# Processing Record 41 of Set 2 | lakes entrance
# Processing Record 42 of Set 2 | huilong
# Processing Record 43 of Set 2 | ponta do sol
# Processing Record 44 of Set 2 | egvekinot
# Processing Record 45 of Set 2 | kabanjahe
# Processing Record 46 of Set 2 | altenholz
# Processing Record 47 of Set 2 | cherskiy
# Processing Record 48 of Set 2 | vadso
# Processing Record 49 of Set 2 | mazatan
# Processing Record 50 of Set 2 | punta arenas
# Processing Record 1 of Set 3 | beringovskiy
# Processing Record 2 of Set 3 | kavieng
# Processing Record 3 of Set 3 | severomuysk
# Processing Record 4 of Set 3 | itarema
# Processing Record 5 of Set 3 | mudgee
# Processing Record 6 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 7 of Set 3 | karamay
# City not found. Skipping...
# Processing Record 8 of Set 3 | hasilpur
# Processing Record 9 of Set 3 | mentok
# City not found. Skipping...
# Processing Record 10 of Set 3 | kaabong
# Processing Record 11 of Set 3 | guatire
# Processing Record 12 of Set 3 | grootfontein
# Processing Record 13 of Set 3 | kruisfontein
# Processing Record 14 of Set 3 | yulara
# Processing Record 15 of Set 3 | coquimbo
# Processing Record 16 of Set 3 | vila franca do campo
# Processing Record 17 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 18 of Set 3 | margate
# Processing Record 19 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 20 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 21 of Set 3 | santa cruz
# Processing Record 22 of Set 3 | maniwaki
# Processing Record 23 of Set 3 | ringwood
# Processing Record 24 of Set 3 | solnechnyy
# Processing Record 25 of Set 3 | bredasdorp
# Processing Record 26 of Set 3 | port alfred
# Processing Record 27 of Set 3 | qasigiannguit
# Processing Record 28 of Set 3 | tigzirt
# Processing Record 29 of Set 3 | muzhi
# Processing Record 30 of Set 3 | cassia
# Processing Record 31 of Set 3 | balsas
# Processing Record 32 of Set 3 | east london
# Processing Record 33 of Set 3 | taybad
# Processing Record 34 of Set 3 | tiksi
# Processing Record 35 of Set 3 | port hardy
# Processing Record 36 of Set 3 | samarai
# Processing Record 37 of Set 3 | imbituva
# Processing Record 38 of Set 3 | haibowan
# City not found. Skipping...
# Processing Record 39 of Set 3 | galveston
# Processing Record 40 of Set 3 | aldan
# Processing Record 41 of Set 3 | new norfolk
# Processing Record 42 of Set 3 | naze
# Processing Record 43 of Set 3 | tuktoyaktuk
# Processing Record 44 of Set 3 | faanui
# Processing Record 45 of Set 3 | onega
# Processing Record 46 of Set 3 | sampit
# Processing Record 47 of Set 3 | nishihara
# Processing Record 48 of Set 3 | santa marta de tormes
# Processing Record 49 of Set 3 | kaitangata
# Processing Record 50 of Set 3 | carutapera
# Processing Record 1 of Set 4 | rosarito
# Processing Record 2 of Set 4 | tonj
# Processing Record 3 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 4 of Set 4 | turukhansk
# Processing Record 5 of Set 4 | mareeba
# Processing Record 6 of Set 4 | francisco sa
# Processing Record 7 of Set 4 | dingle
# Processing Record 8 of Set 4 | new berlin
# Processing Record 9 of Set 4 | lardos
# Processing Record 10 of Set 4 | tuatapere
# Processing Record 11 of Set 4 | hirara
# Processing Record 12 of Set 4 | celestun
# Processing Record 13 of Set 4 | walvis bay
# Processing Record 14 of Set 4 | tiarei
# Processing Record 15 of Set 4 | parana
# Processing Record 16 of Set 4 | teshie
# Processing Record 17 of Set 4 | bosaso
# Processing Record 18 of Set 4 | hofn
# Processing Record 19 of Set 4 | markala
# Processing Record 20 of Set 4 | cape town
# Processing Record 21 of Set 4 | lages
# Processing Record 22 of Set 4 | kodiak
# Processing Record 23 of Set 4 | shediac
# Processing Record 24 of Set 4 | tautira
# Processing Record 25 of Set 4 | port elizabeth
# Processing Record 26 of Set 4 | rawson
# Processing Record 27 of Set 4 | ribeira grande
# Processing Record 28 of Set 4 | sao joao da barra
# Processing Record 29 of Set 4 | beloha
# Processing Record 30 of Set 4 | bethel
# Processing Record 31 of Set 4 | pangkalanbuun
# Processing Record 32 of Set 4 | opotiki
# Processing Record 33 of Set 4 | curvelo
# Processing Record 34 of Set 4 | beysehir
# Processing Record 35 of Set 4 | yendi
# Processing Record 36 of Set 4 | curuca
# Processing Record 37 of Set 4 | ayan
# Processing Record 38 of Set 4 | pabna
# Processing Record 39 of Set 4 | katsuura
# Processing Record 40 of Set 4 | utiroa
# City not found. Skipping...
# Processing Record 41 of Set 4 | caconda
# Processing Record 42 of Set 4 | kedgwick
# Processing Record 43 of Set 4 | najran
# Processing Record 44 of Set 4 | kyren
# Processing Record 45 of Set 4 | bengkulu
# Processing Record 46 of Set 4 | tulum
# Processing Record 47 of Set 4 | ustyuzhna
# Processing Record 48 of Set 4 | tomatlan
# Processing Record 49 of Set 4 | camocim
# Processing Record 50 of Set 4 | victoria
# Processing Record 1 of Set 5 | mount isa
# Processing Record 2 of Set 5 | tasbuget
# City not found. Skipping...
# Processing Record 3 of Set 5 | buldana
# Processing Record 4 of Set 5 | lata
# Processing Record 5 of Set 5 | castro
# Processing Record 6 of Set 5 | talnakh
# Processing Record 7 of Set 5 | carnarvon
# Processing Record 8 of Set 5 | chokurdakh
# Processing Record 9 of Set 5 | sechura
# Processing Record 10 of Set 5 | nagato
# Processing Record 11 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 12 of Set 5 | macheng
# Processing Record 13 of Set 5 | linapacan
# City not found. Skipping...
# Processing Record 14 of Set 5 | quatre cocos
# Processing Record 15 of Set 5 | harihar
# Processing Record 16 of Set 5 | aklavik
# Processing Record 17 of Set 5 | viedma
# Processing Record 18 of Set 5 | zelezna ruda
# Processing Record 19 of Set 5 | sao filipe
# Processing Record 20 of Set 5 | dikson
# Processing Record 21 of Set 5 | carrboro
# Processing Record 22 of Set 5 | cotonou
# Processing Record 23 of Set 5 | beypur
# City not found. Skipping...
# Processing Record 24 of Set 5 | killybegs
# Processing Record 25 of Set 5 | iqaluit
# Processing Record 26 of Set 5 | leningradskiy
# Processing Record 27 of Set 5 | ambatofinandrahana
# Processing Record 28 of Set 5 | scottsbluff
# Processing Record 29 of Set 5 | veraval
# Processing Record 30 of Set 5 | alofi
# Processing Record 31 of Set 5 | bambous virieux
# Processing Record 32 of Set 5 | thames
# Processing Record 33 of Set 5 | sabha
# Processing Record 34 of Set 5 | yerbogachen
# Processing Record 35 of Set 5 | nikolskoye
# Processing Record 36 of Set 5 | noumea
# Processing Record 37 of Set 5 | flinders
# Processing Record 38 of Set 5 | mahebourg
# Processing Record 39 of Set 5 | ayacucho
# Processing Record 40 of Set 5 | male
# Processing Record 41 of Set 5 | gualeguay
# Processing Record 42 of Set 5 | ostrovnoy
# Processing Record 43 of Set 5 | balikpapan
# Processing Record 44 of Set 5 | kosh-agach
# Processing Record 45 of Set 5 | geraldton
# Processing Record 46 of Set 5 | labuhan
# Processing Record 47 of Set 5 | cidreira
# Processing Record 48 of Set 5 | ranong
# Processing Record 49 of Set 5 | svarstad
# Processing Record 50 of Set 5 | arlit
# Processing Record 1 of Set 6 | sinjah
# City not found. Skipping...
# Processing Record 2 of Set 6 | urumqi
# Processing Record 3 of Set 6 | bathsheba
# Processing Record 4 of Set 6 | roebourne
# Processing Record 5 of Set 6 | chanute
# Processing Record 6 of Set 6 | tigre
# Processing Record 7 of Set 6 | saldanha
# Processing Record 8 of Set 6 | nanortalik
# Processing Record 9 of Set 6 | sioux lookout
# Processing Record 10 of Set 6 | solsvik
# City not found. Skipping...
# Processing Record 11 of Set 6 | buin
# Processing Record 12 of Set 6 | vao
# Processing Record 13 of Set 6 | beian
# Processing Record 14 of Set 6 | port lincoln
# Processing Record 15 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 16 of Set 6 | sibolga
# Processing Record 17 of Set 6 | oranjemund
# Processing Record 18 of Set 6 | san cristobal
# Processing Record 19 of Set 6 | teya
# Processing Record 20 of Set 6 | sohag
# Processing Record 21 of Set 6 | steamboat springs
# Processing Record 22 of Set 6 | olafsvik
# Processing Record 23 of Set 6 | conceicao da barra
# Processing Record 24 of Set 6 | pisco
# Processing Record 25 of Set 6 | longyearbyen
# Processing Record 26 of Set 6 | ixtapa
# Processing Record 27 of Set 6 | okhotsk
# Processing Record 28 of Set 6 | shieli
# Processing Record 29 of Set 6 | arrecife
# Processing Record 30 of Set 6 | victor harbor
# Processing Record 31 of Set 6 | tazovskiy
# Processing Record 32 of Set 6 | coahuayana
# Processing Record 33 of Set 6 | saint anthony
# Processing Record 34 of Set 6 | obidos
# Processing Record 35 of Set 6 | plettenberg bay
# Processing Record 36 of Set 6 | nelson bay
# Processing Record 37 of Set 6 | ulladulla
# Processing Record 38 of Set 6 | cururupu
# Processing Record 39 of Set 6 | aksehir
# Processing Record 40 of Set 6 | constitucion
# Processing Record 41 of Set 6 | half moon bay
# Processing Record 42 of Set 6 | ormara
# Processing Record 43 of Set 6 | richards bay
# Processing Record 44 of Set 6 | nantucket
# Processing Record 45 of Set 6 | rawlins
# Processing Record 46 of Set 6 | bud
# Processing Record 47 of Set 6 | jurilovca
# Processing Record 48 of Set 6 | chabahar
# Processing Record 49 of Set 6 | hearst
# Processing Record 50 of Set 6 | tambovka
# Processing Record 1 of Set 7 | sarangani
# Processing Record 2 of Set 7 | uige
# Processing Record 3 of Set 7 | kitimat
# Processing Record 4 of Set 7 | te anau
# Processing Record 5 of Set 7 | ceres
# Processing Record 6 of Set 7 | prince rupert
# Processing Record 7 of Set 7 | bac lieu
# Processing Record 8 of Set 7 | pitimbu
# Processing Record 9 of Set 7 | nouadhibou
# Processing Record 10 of Set 7 | hambantota
# Processing Record 11 of Set 7 | nizhniy kuranakh
# Processing Record 12 of Set 7 | chernyshevskiy
# Processing Record 13 of Set 7 | muscat
# Processing Record 14 of Set 7 | kavaratti
# Processing Record 15 of Set 7 | tambopata
# Processing Record 16 of Set 7 | gizo
# Processing Record 17 of Set 7 | basco
# Processing Record 18 of Set 7 | clyde river
# Processing Record 19 of Set 7 | salalah
# Processing Record 20 of Set 7 | warmbad
# Processing Record 21 of Set 7 | vestbygda
# City not found. Skipping...
# Processing Record 22 of Set 7 | metehara
# City not found. Skipping...
# Processing Record 23 of Set 7 | haines junction
# Processing Record 24 of Set 7 | santa helena
# Processing Record 25 of Set 7 | miracema do tocantins
# Processing Record 26 of Set 7 | dubbo
# Processing Record 27 of Set 7 | marsa matruh
# Processing Record 28 of Set 7 | berlevag
# Processing Record 29 of Set 7 | skalistyy
# City not found. Skipping...
# Processing Record 30 of Set 7 | aykhal
# Processing Record 31 of Set 7 | mayo
# Processing Record 32 of Set 7 | slave lake
# Processing Record 33 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 34 of Set 7 | renqiu
# Processing Record 35 of Set 7 | havelock
# Processing Record 36 of Set 7 | calvinia
# Processing Record 37 of Set 7 | milford
# Processing Record 38 of Set 7 | beira
# Processing Record 39 of Set 7 | florestopolis
# Processing Record 40 of Set 7 | navoi
# Processing Record 41 of Set 7 | saint-philippe
# Processing Record 42 of Set 7 | la ronge
# Processing Record 43 of Set 7 | sola
# Processing Record 44 of Set 7 | beipiao
# Processing Record 45 of Set 7 | marystown
# Processing Record 46 of Set 7 | mackenzie
# Processing Record 47 of Set 7 | narsaq
# Processing Record 48 of Set 7 | ancud
# Processing Record 49 of Set 7 | santiago de chuco
# Processing Record 50 of Set 7 | grand-santi
# Processing Record 1 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 2 of Set 8 | taitung
# Processing Record 3 of Set 8 | iranshahr
# Processing Record 4 of Set 8 | oyem
# Processing Record 5 of Set 8 | lanzhou
# Processing Record 6 of Set 8 | pochutla
# Processing Record 7 of Set 8 | ziro
# Processing Record 8 of Set 8 | bonito
# Processing Record 9 of Set 8 | port blair
# Processing Record 10 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 11 of Set 8 | labuan
# Processing Record 12 of Set 8 | cary
# Processing Record 13 of Set 8 | nhamunda
# Processing Record 14 of Set 8 | shakiso
# Processing Record 15 of Set 8 | tidore
# City not found. Skipping...
# Processing Record 16 of Set 8 | muroto
# Processing Record 17 of Set 8 | segou
# Processing Record 18 of Set 8 | aswan
# Processing Record 19 of Set 8 | port macquarie
# Processing Record 20 of Set 8 | meulaboh
# Processing Record 21 of Set 8 | dayong
# Processing Record 22 of Set 8 | takoradi
# Processing Record 23 of Set 8 | coihaique
# Processing Record 24 of Set 8 | olinda
# Processing Record 25 of Set 8 | roma
# Processing Record 26 of Set 8 | saint-georges
# Processing Record 27 of Set 8 | kysyl-syr
# Processing Record 28 of Set 8 | laguna
# Processing Record 29 of Set 8 | barbosa ferraz
# Processing Record 30 of Set 8 | highland park
# Processing Record 31 of Set 8 | trelleborg
# Processing Record 32 of Set 8 | saraza
# Processing Record 33 of Set 8 | phan thiet
# Processing Record 34 of Set 8 | arkhara
# Processing Record 35 of Set 8 | saint-dizier
# Processing Record 36 of Set 8 | kuusamo
# Processing Record 37 of Set 8 | praia
# Processing Record 38 of Set 8 | andujar
# Processing Record 39 of Set 8 | saint george
# Processing Record 40 of Set 8 | yingzhong
# City not found. Skipping...
# Processing Record 41 of Set 8 | ust-maya
# Processing Record 42 of Set 8 | tabuk
# Processing Record 43 of Set 8 | klaksvik
# Processing Record 44 of Set 8 | gatton
# Processing Record 45 of Set 8 | koutiala
# Processing Record 46 of Set 8 | feldkirchen
# Processing Record 47 of Set 8 | sinkat
# City not found. Skipping...
# Processing Record 48 of Set 8 | harper
# Processing Record 49 of Set 8 | russell
# Processing Record 50 of Set 8 | pevek
# Processing Record 1 of Set 9 | sinnamary
# Processing Record 2 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 3 of Set 9 | durango
# Processing Record 4 of Set 9 | bandarbeyla
# Processing Record 5 of Set 9 | am timan
# Processing Record 6 of Set 9 | omsukchan
# Processing Record 7 of Set 9 | stamsund
# City not found. Skipping...
# Processing Record 8 of Set 9 | kyle of lochalsh
# City not found. Skipping...
# Processing Record 9 of Set 9 | grand centre
# City not found. Skipping...
# Processing Record 10 of Set 9 | olga
# Processing Record 11 of Set 9 | lorengau
# Processing Record 12 of Set 9 | kasumkent
# Processing Record 13 of Set 9 | alice springs
# Processing Record 14 of Set 9 | pimentel
# Processing Record 15 of Set 9 | marzuq
# Processing Record 16 of Set 9 | irtyshskiy
# Processing Record 17 of Set 9 | jamkhed
# Processing Record 18 of Set 9 | roald
# Processing Record 19 of Set 9 | tynda
# Processing Record 20 of Set 9 | colares
# Processing Record 21 of Set 9 | ust-kulom
# Processing Record 22 of Set 9 | aksu
# Processing Record 23 of Set 9 | wainwright
# Processing Record 24 of Set 9 | kahului
# Processing Record 25 of Set 9 | navolato
# Processing Record 26 of Set 9 | wadi maliz
# Processing Record 27 of Set 9 | japura
# Processing Record 28 of Set 9 | vila velha
# Processing Record 29 of Set 9 | bastia
# Processing Record 30 of Set 9 | zhanatas
# City not found. Skipping...
# Processing Record 31 of Set 9 | kumba
# Processing Record 32 of Set 9 | skeldon
# Processing Record 33 of Set 9 | lasa
# Processing Record 34 of Set 9 | sur
# Processing Record 35 of Set 9 | severo-yeniseyskiy
# Processing Record 36 of Set 9 | tura
# Processing Record 37 of Set 9 | aybak
# City not found. Skipping...
# Processing Record 38 of Set 9 | yumen
# Processing Record 39 of Set 9 | suntar
# Processing Record 40 of Set 9 | kattivakkam
# Processing Record 41 of Set 9 | lanskroun
# Processing Record 42 of Set 9 | khatanga
# Processing Record 43 of Set 9 | taksimo
# Processing Record 44 of Set 9 | khuzhir
# Processing Record 45 of Set 9 | nicoya
# Processing Record 46 of Set 9 | kamaishi
# Processing Record 47 of Set 9 | ginir
# Processing Record 48 of Set 9 | nalobikha
# Processing Record 49 of Set 9 | jacareacanga
# Processing Record 50 of Set 9 | port augusta
# Processing Record 1 of Set 10 | acapulco
# Processing Record 2 of Set 10 | izberbash
# Processing Record 3 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 4 of Set 10 | traralgon
# Processing Record 5 of Set 10 | capao bonito
# Processing Record 6 of Set 10 | ilukste
# Processing Record 7 of Set 10 | chumikan
# Processing Record 8 of Set 10 | gat
# Processing Record 9 of Set 10 | zhaozhou
# Processing Record 10 of Set 10 | kumi
# Processing Record 11 of Set 10 | odweyne
# Processing Record 12 of Set 10 | kupang
# Processing Record 13 of Set 10 | sitka
# Processing Record 14 of Set 10 | laminusa
# Processing Record 15 of Set 10 | lavrentiya
# Processing Record 16 of Set 10 | stokmarknes
# Processing Record 17 of Set 10 | moose factory
# Processing Record 18 of Set 10 | morondava
# Processing Record 19 of Set 10 | pooler
# Processing Record 20 of Set 10 | tayu
# Processing Record 21 of Set 10 | ngunguru
# Processing Record 22 of Set 10 | escanaba
# Processing Record 23 of Set 10 | goba
# Processing Record 24 of Set 10 | santo anastacio
# Processing Record 25 of Set 10 | puerto pinasco
# City not found. Skipping...
# Processing Record 26 of Set 10 | coxim
# Processing Record 27 of Set 10 | alta floresta
# Processing Record 28 of Set 10 | padang
# Processing Record 29 of Set 10 | lovozero
# Processing Record 30 of Set 10 | anchorage
# Processing Record 31 of Set 10 | rochegda
# Processing Record 32 of Set 10 | portoferraio
# Processing Record 33 of Set 10 | forssa
# Processing Record 34 of Set 10 | fortuna
# Processing Record 35 of Set 10 | wajir
# Processing Record 36 of Set 10 | nuuk
# Processing Record 37 of Set 10 | mount gambier
# Processing Record 38 of Set 10 | savannah bight
# Processing Record 39 of Set 10 | luderitz
# Processing Record 40 of Set 10 | uren
# Processing Record 41 of Set 10 | nome
# Processing Record 42 of Set 10 | labutta
# City not found. Skipping...
# Processing Record 43 of Set 10 | hihifo
# City not found. Skipping...
# Processing Record 44 of Set 10 | jose de freitas
# Processing Record 45 of Set 10 | lethem
# Processing Record 46 of Set 10 | huarmey
# Processing Record 47 of Set 10 | taree
# Processing Record 48 of Set 10 | ryotsu
# Processing Record 49 of Set 10 | almirante
# Processing Record 50 of Set 10 | ust-kuyga
# Processing Record 1 of Set 11 | belyy yar
# Processing Record 2 of Set 11 | podosinovets
# Processing Record 3 of Set 11 | guerrero negro
# Processing Record 4 of Set 11 | portel
# Processing Record 5 of Set 11 | cobija
# Processing Record 6 of Set 11 | thaton
# Processing Record 7 of Set 11 | murwara
# Processing Record 8 of Set 11 | avera
# Processing Record 9 of Set 11 | rocha
# Processing Record 10 of Set 11 | encruzilhada do sul
# Processing Record 11 of Set 11 | scarborough
# Processing Record 12 of Set 11 | macau
# Processing Record 13 of Set 11 | tianpeng
# Processing Record 14 of Set 11 | fonte boa
# Processing Record 15 of Set 11 | monrovia
# Processing Record 16 of Set 11 | bobo dioulasso
# Processing Record 17 of Set 11 | raudeberg
# Processing Record 18 of Set 11 | malakal
# Processing Record 19 of Set 11 | gravdal
# Processing Record 20 of Set 11 | moree
# Processing Record 21 of Set 11 | rudbar
# Processing Record 22 of Set 11 | presidencia roque saenz pena
# Processing Record 23 of Set 11 | araouane
# Processing Record 24 of Set 11 | corigliano calabro
# Processing Record 25 of Set 11 | saint-augustin
# Processing Record 26 of Set 11 | bundaberg
# Processing Record 27 of Set 11 | jinchang
# Processing Record 28 of Set 11 | bjornevatn
# Processing Record 29 of Set 11 | broome
# Processing Record 30 of Set 11 | mandiana
# Processing Record 31 of Set 11 | kudahuvadhoo
# Processing Record 32 of Set 11 | plouzane
# Processing Record 33 of Set 11 | san giuseppe jato
# Processing Record 34 of Set 11 | eldorado
# Processing Record 35 of Set 11 | kuruman
# Processing Record 36 of Set 11 | tenkodogo
# Processing Record 37 of Set 11 | westlock
# Processing Record 38 of Set 11 | cayenne
# Processing Record 39 of Set 11 | atar
# Processing Record 40 of Set 11 | altay
# Processing Record 41 of Set 11 | jalu
# Processing Record 42 of Set 11 | latina
# Processing Record 43 of Set 11 | bukachacha
# Processing Record 44 of Set 11 | klyuchevskiy
# Processing Record 45 of Set 11 | cockburn harbour
# City not found. Skipping...
# Processing Record 46 of Set 11 | camacha
# Processing Record 47 of Set 11 | nangong
# Processing Record 48 of Set 11 | pag
# Processing Record 49 of Set 11 | zhigansk
# Processing Record 50 of Set 11 | kelso
# Processing Record 1 of Set 12 | caiaponia
# Processing Record 2 of Set 12 | arraias
# Processing Record 3 of Set 12 | sonoita
# Processing Record 4 of Set 12 | ust-tsilma
# Processing Record 5 of Set 12 | panalingaan
# Processing Record 6 of Set 12 | tessalit
# Processing Record 7 of Set 12 | pelym
# Processing Record 8 of Set 12 | ilulissat
# Processing Record 9 of Set 12 | acajutla
# Processing Record 10 of Set 12 | belmonte
# Processing Record 11 of Set 12 | lazaro cardenas
# Processing Record 12 of Set 12 | natal
# Processing Record 13 of Set 12 | plaridel
# Processing Record 14 of Set 12 | ellensburg
# Processing Record 15 of Set 12 | hays
# Processing Record 16 of Set 12 | peterborough
# Processing Record 17 of Set 12 | thai binh
# Processing Record 18 of Set 12 | katangli
# Processing Record 19 of Set 12 | slubice
# Processing Record 20 of Set 12 | sabancuy
# Processing Record 21 of Set 12 | san ignacio
# Processing Record 22 of Set 12 | taltal
# Processing Record 23 of Set 12 | komsomolskiy
# Processing Record 24 of Set 12 | gamba
# Processing Record 25 of Set 12 | intipuca
# Processing Record 26 of Set 12 | abu dhabi
# Processing Record 27 of Set 12 | goundam
# Processing Record 28 of Set 12 | snasa
# Processing Record 29 of Set 12 | port ellen
# City not found. Skipping...
# Processing Record 30 of Set 12 | sault sainte marie
# Processing Record 31 of Set 12 | humaita
# Processing Record 32 of Set 12 | kampot
# Processing Record 33 of Set 12 | portland
# Processing Record 34 of Set 12 | amargosa
# Processing Record 35 of Set 12 | thinadhoo
# Processing Record 36 of Set 12 | kangasala
# Processing Record 37 of Set 12 | nea karvali
# Processing Record 38 of Set 12 | san pedro de macoris
# Processing Record 39 of Set 12 | harer
# Processing Record 40 of Set 12 | mastic beach
# Processing Record 41 of Set 12 | obuasi
# Processing Record 42 of Set 12 | manzanillo
# Processing Record 43 of Set 12 | hare bay
# Processing Record 44 of Set 12 | halifax
# Processing Record 45 of Set 12 | kawalu
# Processing Record 46 of Set 12 | honggang
# Processing Record 47 of Set 12 | cartagena del chaira
# Processing Record 48 of Set 12 | machacamarca
# Processing Record 49 of Set 12 | salekhard
# Processing Record 50 of Set 12 | virginia beach
# Processing Record 1 of Set 13 | pangnirtung
# Processing Record 2 of Set 13 | kambam
# Processing Record 3 of Set 13 | tanout
# Processing Record 4 of Set 13 | mandera
# Processing Record 5 of Set 13 | bonavista
# Processing Record 6 of Set 13 | waingapu
# Processing Record 7 of Set 13 | yar-sale
# Processing Record 8 of Set 13 | tungor
# Processing Record 9 of Set 13 | san quintin
# Processing Record 10 of Set 13 | junagarh
# Processing Record 11 of Set 13 | juneau
# Processing Record 12 of Set 13 | mlawa
# Processing Record 13 of Set 13 | san matias
# Processing Record 14 of Set 13 | kotelnich
# Processing Record 15 of Set 13 | llangefni
# Processing Record 16 of Set 13 | hamilton
# Processing Record 17 of Set 13 | shingu
# Processing Record 18 of Set 13 | nizhniy baskunchak
# Processing Record 19 of Set 13 | bilibino
# Processing Record 20 of Set 13 | tarusa
# Processing Record 21 of Set 13 | port-cartier
# Processing Record 22 of Set 13 | muros
# Processing Record 23 of Set 13 | arbroath
# Processing Record 24 of Set 13 | seymchan
# Processing Record 25 of Set 13 | pasni
# Processing Record 26 of Set 13 | troitsko-pechorsk
# Processing Record 27 of Set 13 | berkak
# Processing Record 28 of Set 13 | halalo
# City not found. Skipping...
# Processing Record 29 of Set 13 | ibra
# Processing Record 30 of Set 13 | gornopravdinsk
# Processing Record 31 of Set 13 | khanpur
# Processing Record 32 of Set 13 | la rioja
# Processing Record 33 of Set 13 | bodden town
# Processing Record 34 of Set 13 | phuket
# Processing Record 35 of Set 13 | medea
# Processing Record 36 of Set 13 | ouadda
# Processing Record 37 of Set 13 | kharan
# Processing Record 38 of Set 13 | marawi
# Processing Record 39 of Set 13 | nova granada
# Processing Record 40 of Set 13 | marsh harbour
# Processing Record 41 of Set 13 | ambon
# Processing Record 42 of Set 13 | isilkul
# Processing Record 43 of Set 13 | kovur
# Processing Record 44 of Set 13 | agdam
# Processing Record 45 of Set 13 | beidao
# Processing Record 46 of Set 13 | quang ngai
# Processing Record 47 of Set 13 | kambove
# Processing Record 48 of Set 13 | rosehearty
# Processing Record 49 of Set 13 | vardo
# Processing Record 50 of Set 13 | taoudenni
# Processing Record 1 of Set 14 | enshi
# Processing Record 2 of Set 14 | fez
# Processing Record 3 of Set 14 | manglisi
# Processing Record 4 of Set 14 | hope
# Processing Record 5 of Set 14 | tadine
# Processing Record 6 of Set 14 | sao raimundo nonato
# Processing Record 7 of Set 14 | huanren
# Processing Record 8 of Set 14 | kouango
# Processing Record 9 of Set 14 | biak
# Processing Record 10 of Set 14 | barawe
# City not found. Skipping...
# Processing Record 11 of Set 14 | tilichiki
# Processing Record 12 of Set 14 | mirpur sakro
# Processing Record 13 of Set 14 | aleksandrovskoye
# Processing Record 14 of Set 14 | piacabucu
# Processing Record 15 of Set 14 | auriflama
# Processing Record 16 of Set 14 | maldonado
# Processing Record 17 of Set 14 | safonovo
# Processing Record 18 of Set 14 | chapais
# Processing Record 19 of Set 14 | adrar
# Processing Record 20 of Set 14 | veinticinco de mayo
# Processing Record 21 of Set 14 | muisne
# Processing Record 22 of Set 14 | nesna
# Processing Record 23 of Set 14 | alotau
# City not found. Skipping...
# Processing Record 24 of Set 14 | sovetskiy
# Processing Record 25 of Set 14 | buraydah
# Processing Record 26 of Set 14 | kisogawa
# City not found. Skipping...
# Processing Record 27 of Set 14 | rockingham
# Processing Record 28 of Set 14 | saquarema
# Processing Record 29 of Set 14 | saint-denis
# Processing Record 30 of Set 14 | namatanai
# Processing Record 31 of Set 14 | spasskoye
# Processing Record 32 of Set 14 | dunedin
# Processing Record 33 of Set 14 | les cayes
# Processing Record 34 of Set 14 | eregli
# Processing Record 35 of Set 14 | killarney
# Processing Record 36 of Set 14 | akdepe
# Processing Record 37 of Set 14 | porto novo
# Processing Record 38 of Set 14 | kurumkan
# Processing Record 39 of Set 14 | san jose
# Processing Record 40 of Set 14 | tiznit
# Processing Record 41 of Set 14 | jurmala
# Processing Record 42 of Set 14 | poum
# Processing Record 43 of Set 14 | samalaeulu
# City not found. Skipping...
# Processing Record 44 of Set 14 | jiddah
# City not found. Skipping...
# Processing Record 45 of Set 14 | hami
# Processing Record 46 of Set 14 | xixiang
# Processing Record 47 of Set 14 | morro bay
# Processing Record 48 of Set 14 | nemuro
# Processing Record 49 of Set 14 | yabrud
# Processing Record 50 of Set 14 | nieuwpoort
# Processing Record 1 of Set 15 | banda aceh
# Processing Record 2 of Set 15 | pacific grove
# Processing Record 3 of Set 15 | el carmen
# Processing Record 4 of Set 15 | talsi
# Processing Record 5 of Set 15 | dickinson
# Processing Record 6 of Set 15 | ashdod
# Processing Record 7 of Set 15 | abashiri
# Processing Record 8 of Set 15 | salinopolis
# Processing Record 9 of Set 15 | floro
# Processing Record 10 of Set 15 | boa vista
# Processing Record 11 of Set 15 | louisbourg
# City not found. Skipping...
# Processing Record 12 of Set 15 | xining
# Processing Record 13 of Set 15 | pangai
# Processing Record 14 of Set 15 | howard springs
# Processing Record 15 of Set 15 | hua hin
# Processing Record 16 of Set 15 | emerald
# Processing Record 17 of Set 15 | umm durman
# City not found. Skipping...
# Processing Record 18 of Set 15 | yushala
# Processing Record 19 of Set 15 | timra
# Processing Record 20 of Set 15 | launceston
# Processing Record 21 of Set 15 | bur gabo
# City not found. Skipping...
# Processing Record 22 of Set 15 | lubango
# Processing Record 23 of Set 15 | vestmannaeyjar
# Processing Record 24 of Set 15 | petukhovo
# Processing Record 25 of Set 15 | baft
# Processing Record 26 of Set 15 | great yarmouth
# Processing Record 27 of Set 15 | sorsk
# Processing Record 28 of Set 15 | voh
# Processing Record 29 of Set 15 | leh
# Processing Record 30 of Set 15 | padampur
# Processing Record 31 of Set 15 | melchor de mencos
# Processing Record 32 of Set 15 | ugoofaaru
# Processing Record 33 of Set 15 | awjilah
# Processing Record 34 of Set 15 | ferrandina
# Processing Record 35 of Set 15 | manzil tamim
# City not found. Skipping...
# Processing Record 36 of Set 15 | cherdyn
# Processing Record 37 of Set 15 | tall kayf
# Processing Record 38 of Set 15 | iquitos
# Processing Record 39 of Set 15 | chunhuhub
# Processing Record 40 of Set 15 | pavlodar
# Processing Record 41 of Set 15 | los llanos de aridane
# Processing Record 42 of Set 15 | port hawkesbury
# Processing Record 43 of Set 15 | atyrau
# Processing Record 44 of Set 15 | bubaque
# Processing Record 45 of Set 15 | port hedland
# Processing Record 46 of Set 15 | catanzaro
# Processing Record 47 of Set 15 | sataua
# City not found. Skipping...
# Processing Record 48 of Set 15 | deputatskiy
# Processing Record 49 of Set 15 | kamwenge
# Processing Record 50 of Set 15 | aleksandrov gay
# Processing Record 1 of Set 16 | ambilobe
# Processing Record 2 of Set 16 | kivioli
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 693

# %%
# Add the data to a DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Torbay      CA  47.6666  -52.7314     30.27        87         100
# 1           Kutum      SD  14.2000   24.6667     55.76        24           3
# 2         Yeppoon      AU -23.1333  150.7333     85.78        73          40
# 3         Mataura      NZ -46.1927  168.8643     64.47        39         100
# 4           Vaini      TO -21.2000 -175.2000     84.36        84          40
# 5        Thompson      CA  55.7435  -97.8558    -23.64        76           0
# 6      Butaritari      KI   3.0707  172.7902     81.28        77          67
# 7        Hermanus      ZA -34.4187   19.2345     68.90        77          85
# 8  Cabo San Lucas      MX  22.8909 -109.9124     69.10        56          66
# 9           Bluff      NZ -46.6000  168.3333     64.80        66         100
#
#    Wind Speed Current Description
# 0       10.36          light snow
# 1        6.26           clear sky
# 2       20.31    scattered clouds
# 3        5.77     overcast clouds
# 4       10.36    scattered clouds
# 5        8.05           clear sky
# 6       12.15          light rain
# 7       19.17     overcast clouds
# 8        6.35       broken clouds
# 9        7.36     overcast clouds

# %%
# Export the DataFrame as a CSV and save in the Weather_Database folder
output_data_file = "WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")
